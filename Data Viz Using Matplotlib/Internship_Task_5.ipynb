# %% [markdown]
# PHN Technology Internship Task 5

# %% [markdown]
# Import Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Write a Python code to Create a figure with 2x2 subplots.

# %%
fig, axs = plt.subplots(2, 2)
fig.tight_layout(pad=3.0)

# %%
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = [23, 56, 41, 62, 19]

fig, ax = plt.subplots()
ax.bar(categories, values, color='red')
ax.set_title('Bar Chart')
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %% [markdown]
# 2. In the first subplot (top-left), plot a bar chart using the following data:
# Categories: ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
# Values: [23, 56, 41, 62, 19]

# %%
# Data for histogram
data = [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]

fig, ax = plt.subplots()
ax.hist(data, bins=5, color='green')
ax.set_title('Histogram')
ax.set_xlabel('Data')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# 3. In the second subplot (top-right), plot a histogram using the following data:
# Data: [12, 17, 21, 18, 14, 13, 16, 9, 12, 15, 19, 11, 14, 16, 20, 18, 15, 13, 16, 11, 10]

# %%
labels = ['Apple', 'Banana', 'Orange', 'Mango']
sizes = [30, 25, 15, 30]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
ax.set_title('Pie Chart')
# Out:
# Text(0.5, 1.0, 'Pie Chart')

# %% [markdown]
# 4. In the third subplot (bottom-left), plot a pie chart using the following data:
# Labels: ['Apple', 'Banana', 'Orange', 'Mango']
# Sizes: [30, 25, 15, 30]

# %%
x_values = [1, 2, 3, 4, 5]
y_values = [2, 5, 3, 6, 4]

fig, ax = plt.subplots()
ax.scatter(x_values, y_values, color='black')
ax.set_title('Scatter Plot')
ax.set_xlabel('X values')
ax.set_ylabel('Y values')
# Out:
# Text(0, 0.5, 'Y values')

# %%
plt.show()

# %%
plt.savefig('subplots_figure.png')

print("Figure saved as 'subplots_figure.png'")
# Out:
# Figure saved as 'subplots_figure.png'
